# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("E:\movie imdb\lowest_ranked_movies_data.csv")
df
# Out:
#     rank                                           name  year certification  \
# 0      1                                 Disaster Movie  2008         PG-13
# 1      2                       Manos: The Hands of Fate  1966     Not Rated
# 2      3                     Birdemic: Shock and Terror  2010     Not Rated
# 3      4                   Superbabies: Baby Geniuses 2  2004            PG
# 4      5                        The Hottie & the Nottie  2008         PG-13
# ..   ...                                            ...   ...           ...
# 95    96                                  The Love Guru  2008         PG-13
# 96    97                             The Hungover Games  2014             R
# 97    98  In the Name of the King: A Dungeon Siege Tale  2007         PG-13
# 98    99                                   The Avengers  1998         PG-13
# 99   100             The Flintstones in Viva Rock Vegas  2000            PG
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("E:\movie imdb\lowest_ranked_movies_data.csv")
#create a smaller dataframe
small_df=df[['title', 'release_date', 'budget', 'revenue', 'runtime']]
result=small_df.sort_values('release_date')
("DataFrame based on release date.")
(result)

# %%
df2=df[df['year']>2005][['name', 'year']]

# %%
df2
# Out:
#                                              name  year
# 0                                  Disaster Movie  2008
# 2                      Birdemic: Shock and Terror  2010
# 4                         The Hottie & the Nottie  2008
# 5                 Kirk Cameron's Saving Christmas  2014
# 8                                      Epic Movie  2007
# 9                                           Radhe  2021
# 11                                   Pledge This!  2006
# 13                           Dragonball Evolution  2009
# 14                                         Race 3  2018
# 16                                     Foodfight!  2012
# 18                                 Turks in Space  2006
# 19                              Meet the Spartans  2008
# 21                                     Date Movie  2006
# 22                                           Cats  2019
# 26       The Human Centipede III (Final Sequence)  2015
# 27                                     Cosmic Sin  2021
# ...

# %%
df2.sort_values("year",ascending=False)
# Out:
#                                              name  year
# 44               Winnie the Pooh: Blood and Honey  2023
# 43                                      Adipurush  2023
# 33                       Jeepers Creepers: Reborn  2022
# 32                             365 Days: This Day  2022
# 36                          The Cost of Deception  2021
# 27                                     Cosmic Sin  2021
# 9                                           Radhe  2021
# 55                                         Breach  2020
# 54                                         Laxmii  2020
# 37                                       365 Days  2020
# 73                                       Baaghi 3  2020
# 48                          Student of the Year 2  2019
# 22                                           Cats  2019
# 84                                Black Christmas  2019
# 14                                         Race 3  2018
# 52                                 The Open House  2018
# ...

# %%
df2[::2]
# Out:
#                                          name  year
# 0                              Disaster Movie  2008
# 4                     The Hottie & the Nottie  2008
# 8                                  Epic Movie  2007
# 11                               Pledge This!  2006
# 14                                     Race 3  2018
# 18                             Turks in Space  2006
# 21                                 Date Movie  2006
# 26   The Human Centipede III (Final Sequence)  2015
# 31               Mega Shark vs. Giant Octopus  2009
# 33                   Jeepers Creepers: Reborn  2022
# 36                      The Cost of Deception  2021
# 38        Enes Batur: Imagination or Reality?  2018
# 40                              Jack and Jill  2011
# 44           Winnie the Pooh: Blood and Honey  2023
# 48                      Student of the Year 2  2019
# 50                              Vampires Suck  2010
# 53                         The Starving Games  2013
# ...
