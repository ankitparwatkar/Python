# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("E:\movie imdb\players.csv")

# %%
df
# Out:
#                          Player       Span  Mat  Inns  NO   Runs   HS    Ave  \
# 0            SR Tendulkar (IND)  1989-2013  664   782  74  34357  248  48.52
# 1   KC Sangakkara (Asia/ICC/SL)  2000-2015  594   666  67  28016  319  46.77
# 2          RT Ponting (AUS/ICC)  1995-2012  560   668  70  27483  257  45.95
# 3                 V Kohli (IND)  2008-2024  538   601  87  27134  254  52.78
# 4    DPMD Jayawardene (Asia/SL)  1997-2015  652   725  62  25957  374  39.15
# ..                          ...        ...  ...   ...  ..    ...  ...    ...
# 89              G Gambhir (IND)  2003-2016  242   283  18  10324  206  38.95
# 90              TWM Latham (NZ)  2012-2024  258   309  26  10278  264  36.31
# 91              BKG Mendis (SL)  2015-2024  278   333  19  10244  245  32.62
# 92                MD Crowe (NZ)  1982-1995  220   271  29  10148  299  41.93
# 93              GW Flower (ZIM)  1992-2010  288   337  24  10028  201  32.03
#
#        BF     SR  100   50   0    4s   6s
# ...

# %%
df.value_counts()
# Out:
# Player                   Span       Mat  Inns  NO  Runs   HS   Ave    BF     SR     100  50   0   4s    6s
# A Flower (ZIM)           1992-2003  276  320   35  11580  232  40.63  19733  58.68  16   82   18  1075  46     1
# Misbah-ul-Haq (PAK)      2001-2017  276  315   64  11132  161  44.35  19386  57.42  10   84   17  898   190    1
# RG Sharma (IND)          2007-2024  488  519   65  19367  264  42.65  22186  87.29  48   107  34  1865  624    1
# RB Richardson (WI)       1983-1996  310  363   42  12197  194  37.99  22199  54.82  21   71   16  1302  77     1
# R Dravid (Asia/ICC/IND)  1996-2012  509  605   72  24208  270  45.41  46564  51.98  48   146  21  2604  66     1
#                                                                                                               ..
# GW Flower (ZIM)          1992-2010  288  337   24  10028  201  32.03  19736  50.81  12   55   34  906   53     1
# ...

# %%
df.values
# Out:
# array([['SR Tendulkar (IND)', '1989-2013', 664, ..., 34, 4076, 264],
#        ['KC Sangakkara (Asia/ICC/SL)', '2000-2015', 594, ..., 28, 3015,
#         159],
#        ['RT Ponting (AUS/ICC)', '1995-2012', 560, ..., 39, 2781, 246],
#        ...,
#        ['BKG Mendis (SL)', '2015-2024', 278, ..., 33, 1087, 195],
#        ['MD Crowe (NZ)', '1982-1995', 220, ..., 12, 1037, 56],
#        ['GW Flower (ZIM)', '1992-2010', 288, ..., 34, 906, 53]],
#       dtype=object)

# %%
#plotting Players and Runs on graph
xpoints=df['Player']
ypoints=df['Runs']

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#plotting the entire dataframe using seaborn liabrary
sns.displot(df)
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#classifying players on bases on players average
sns.regplot(x='Runs', y='Ave', data=df)
plt.show()

# %%
#classifying players on bases on players balls faced in entire career
sns.regplot(x='Runs', y='BF', data=df)
plt.show()

# %%
#classifying players on bases on players strike rate in entire career
sns.regplot(x='Runs', y='SR', data=df)
plt.show()

# %%
#classifying players on bases on players century[100's] in entire career
sns.regplot(x='Runs', y='100', data=df)
plt.show()

# %%
#classifying players on bases on players half-century[50's] in entire career
sns.regplot(x='Runs', y='50', data=df)
plt.show()

# %%
#classifying players on bases on players balls faced in entire career through histogram repersentation
sns.histplot(x='Runs', y='BF', bins=10, data=df)
plt.show()
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#classifying players on bases on players average in entire career through histogram repersentation
sns.histplot(x='Runs', y='Ave', kde=20, bins=30, hue='SR', data=df)
plt.show()
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
